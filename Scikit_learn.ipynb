# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_circles

# Creamos nuestros datos artificiales, donde buscaremos clasificar dos anillos concéntricos de datos.
X, Y = make_circles(n_samples=500, factor=0.5, noise=0.05)

# Resolución del mapa de predicción.
res = 100

# Coordenadas del mapa de predicción.
_x0 = np.linspace(-1.5, 1.5, res)
_x1 = np.linspace(-1.5, 1.5, res)

# Input con cada combinación de coordenadas del mapa de predicción.
_pX = np.array(np.meshgrid(_x0, _x1)).T.reshape(-1, 2)

# Objeto vacío de 0.5 del mapa de predicción.
_pY = np.zeros((res, res)) + 0.5

# Visualización del mapa de predicción
plt.figure(figsize=(8, 8))
plt.pcolormesh(_x0, _x1, _pY, cmap="coolwarm", vmin=0, vmax=1, shading='auto')

# Visualización de la nube de datos.
plt.scatter(X[Y == 0, 0], X[Y == 0, 1], c="skyblue")
plt.scatter(X[Y == 1, 0], X[Y == 1, 1], c="salmon")

plt.tick_params(labelbottom=False, labelleft=False)
plt.show()

# %%
import sklearn as sk
import sklearn.neural_network

from IPython.core.display import display, HTML


lr =0.01            #learning rate
nn = [2, 16, 8, 1]   #numero de neuronas en cada capa

#Creamos el objeto del modelo de red neuronal multicapa.
clf = sk.neural_network.MLPRegressor(solver = "sgd",
                                     learning_rate_init = lr,
                                     hidden_layer_sizes = tuple(nn[1:]),
                                     verbose = True,
                                     n_iter_no_change = 1000,
                                     batch_size = 64)

#Y lo entrenamos con
clf.fit(X, Y)
# Out:
# Iteration 1, loss = 0.16620214
# Iteration 2, loss = 0.12121127
# Iteration 3, loss = 0.12019140
# Iteration 4, loss = 0.11440956
# Iteration 5, loss = 0.11314707
# Iteration 6, loss = 0.11257778
# Iteration 7, loss = 0.11177251
# Iteration 8, loss = 0.11132493
# Iteration 9, loss = 0.11053490
# Iteration 10, loss = 0.10983865
# Iteration 11, loss = 0.10915751
# Iteration 12, loss = 0.10854443
# Iteration 13, loss = 0.10785903
# Iteration 14, loss = 0.10721895
# Iteration 15, loss = 0.10656506
# Iteration 16, loss = 0.10580054
# Iteration 17, loss = 0.10503199
# Iteration 18, loss = 0.10462656
# Iteration 19, loss = 0.10397562
# Iteration 20, loss = 0.10372184
# Iteration 21, loss = 0.10311215
# Iteration 22, loss = 0.10273874
# Iteration 23, loss = 0.10224138
# Iteration 24, loss = 0.10187648
# Iteration 25, loss = 0.10148174
# Iteration 26, loss = 0.10113214
# Iteration 27, loss = 0.10087682
# Iteration 28, loss = 0.10032246
# Iteration 29, loss = 0.09999271
# Iteration 30, loss = 0.09936073
# Iteration 31, loss = 0.09856880
# Iteration 32, loss = 0.09761099
# Iteration 33, loss = 0.09650858
# Iteration 34, loss = 0.09539933
# Iteration 35, loss = 0.09421783
# Iteration 36, loss = 0.09339438
# Iteration 37, loss = 0.09233183
# Iteration 38, loss = 0.09138829
# Iteration 39, loss = 0.09024549
# Iteration 40, loss = 0.08895025
# Iteration 41, loss = 0.08800691
